# %%
## Need this to unstack stacked atmospheric regridded variables ##

def ifs_to_latlon(ds):
    '''
    Uses the latitude-longitude information encoded in the regular grid IFS output to reconstructed the regular grid
    '''
    return ds.rename({'value':'latlon'}).set_index(latlon=("lat","lon")).unstack("latlon")

# %%
import xarray as xr
import numpy as np
import intake

eerie_cat=intake.open_catalog("https://raw.githubusercontent.com/eerie-project/intake_catalogues/main/eerie.yaml")

model = 'ifs-fesom2-sr'
expid = 'hist-1950'  # 'highres-future-ssp245', 'hist-1950', 'eerie-control-1950', 'eerie-spinup-1950'
version = 'v20240304'    #
realm='ocean'  # 'ocean' , 'land', 'atmos'
gridspec = 'gr025' # 'native', 'gr025'

cat_data=eerie_cat['dkrz.disk.model-output'][model][expid][version][realm][gridspec]
print(list(cat_data))

ds = cat_data['2D_monthly_avg'].to_dask()
ds
# Out:
# ['2D_daily_avg_1950-2014', '2D_daily_avg_2000-2014', '3D_daily_avg', '2D_monthly_avg', '2D_monthly_avg_mlotst030', '3D_monthly_avg', 'AMOC']
# <xarray.Dataset>
# Dimensions:        (time: 780, lev: 1, lat: 721, lon: 1440, depth: 1)
# Coordinates:
#   * depth          (depth) float64 0.0
#   * lat            (lat) float64 -90.0 -89.75 -89.5 -89.25 ... 89.5 89.75 90.0
#   * lev            (lev) float64 0.0
#   * lon            (lon) float64 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * time           (time) datetime64[ns] 1950-01-31 1950-02-28 ... 2014-12-31
# Data variables:
#     avg_mlotst125  (time, lev, lat, lon) float32 dask.array<chunksize=(32, 1, 721, 1440), meta=np.ndarray>
#     avg_siconc     (time, lev, lat, lon) float32 dask.array<chunksize=(32, 1, 721, 1440), meta=np.ndarray>
#     avg_sisnthick  (time, lev, lat, lon) float32 dask.array<chunksize=(32, 1, 721, 1440), meta=np.ndarray>
#     avg_sithick    (time, lev, lat, lon) float32 dask.array<chunksize=(32, 1, 721, 1440), meta=np.ndarray>
#     avg_siue       (time, lev, lat, lon) float32 dask.array<chunksize=(32, 1, 721, 1440), meta=np.ndarray>
#     avg_sivn       (time, lev, lat, lon) float32 dask.array<chunksize=(32, 1, 721, 1440), meta=np.ndarray>
#     avg_sos        (time, depth, lat, lon) float32 dask.array<chunksize=(32, 1, 721, 1440), meta=np.ndarray>
#     avg_tos        (time, depth, lat, lon) float32 dask.array<chunksize=(32, 1, 721, 1440), meta=np.ndarray>
#     avg_zos        (time, depth, lat, lon) float32 dask.array<chunksize=(32, 1, 721, 1440), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.2.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     frequency:    mon
#     CDO:          Climate Data Operators version 2.2.2 (https://mpimet.mpg.de...
